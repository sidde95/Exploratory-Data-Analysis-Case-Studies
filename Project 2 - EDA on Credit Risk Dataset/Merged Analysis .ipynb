# %%
# importing necessary libraries 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)
# Out:
# C:\Users\roysi\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df_1 = pd.read_csv('appl_df.csv')
df_1.head()
# Out:
#    Unnamed: 0  SK_ID_CURR TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0           0      100002      Y         Cash loans           M            N
# 1           1      100003      N         Cash loans           F            N
# 2           2      100004      N    Revolving loans           M            Y
# 3           3      100006      N         Cash loans           F            N
# 4           4      100007      N         Cash loans           M            N
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0               Y             0          202500.0    406597.5      24700.5
# 1               N             0          270000.0   1293502.5      35698.5
# 2               Y             0           67500.0    135000.0       6750.0
# 3               Y             0          135000.0    312682.5      29686.5
# 4               Y             0          121500.0    513000.0      21865.5
#
#    AMT_GOODS_PRICE NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0         351000.0          Working  Secondary / secondary special
# 1        1129500.0    State servant               Higher education
# 2         135000.0          Working  Secondary / secondary special
# 3         297000.0          Working  Secondary / secondary special
# 4         513000.0          Working  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0  Single / not married  House / apartment       -9461           -637
# 1               Married  House / apartment      -16765          -1188
# 2  Single / not married  House / apartment      -19046           -225
# 3        Civil marriage  House / apartment      -19005          -3039
# 4  Single / not married  House / apartment      -19932          -3038
#
#    FLAG_MOBIL  FLAG_EMAIL  CNT_FAM_MEMBERS  REGION_RATING_CLIENT  \
# 0           1           0              1.0                     2
# 1           1           0              2.0                     1
# 2           1           0              1.0                     2
# 3           1           0              2.0                     2
# 4           1           0              1.0                     2
#
#    REGION_RATING_CLIENT_W_CITY       ORGANIZATION_TYPE  Age  Years_Employed
# 0                            2  Business Entity Type 3   25               2
# 1                            1                  School   45               3
# 2                            2              Government   52               1
# 3                            2  Business Entity Type 3   52               8
# 4                            2                Religion   54               8

# %%
df_1.drop(columns = ['Unnamed: 0'], inplace = True)

# %%
df_2 = pd.read_csv('prev_appl_df.csv')
df_2.head()
# Out:
#    Unnamed: 0  SK_ID_PREV  SK_ID_CURR NAME_CONTRACT_TYPE  AMT_ANNUITY  \
# 0           0     2030495      271877     Consumer loans     1730.430
# 1           1     2802425      108129         Cash loans    25188.615
# 2           2     2523466      122040         Cash loans    15060.735
# 3           3     2819243      176158         Cash loans    47041.335
# 4           4     1784265      202054         Cash loans    31924.395
#
#    AMT_APPLICATION  AMT_CREDIT  AMT_GOODS_PRICE NAME_CASH_LOAN_PURPOSE  \
# 0          17145.0     17145.0          17145.0                    XAP
# 1         607500.0    679671.0         607500.0                    XNA
# 2         112500.0    136444.5         112500.0                    XNA
# 3         450000.0    470790.0         450000.0                    XNA
# 4         337500.0    404055.0         337500.0                Repairs
#
#   NAME_CONTRACT_STATUS  DAYS_DECISION      NAME_PAYMENT_TYPE  \
# 0             Approved             73  Cash through the bank
# 1             Approved            164                    XNA
# 2             Approved            301  Cash through the bank
# 3             Approved            512  Cash through the bank
# 4              Refused            781  Cash through the bank
#
#   CODE_REJECT_REASON NAME_CLIENT_TYPE NAME_GOODS_CATEGORY NAME_PORTFOLIO  \
# 0                XAP         Repeater              Mobile            POS
# 1                XAP         Repeater                 XNA           Cash
# 2                XAP         Repeater                 XNA           Cash
# 3                XAP         Repeater                 XNA           Cash
# 4                 HC         Repeater                 XNA           Cash
#
#               CHANNEL_TYPE  CNT_PAYMENT NAME_YIELD_GROUP
# 0             Country-wide         12.0           middle
# 1           Contact center         36.0       low_action
# 2  Credit and cash offices         12.0             high
# 3  Credit and cash offices         12.0           middle
# 4  Credit and cash offices         24.0             high

# %%
df_2.drop(columns = ['Unnamed: 0'], inplace = True)

# %%
df_2.head()
# Out:
#    SK_ID_PREV  SK_ID_CURR NAME_CONTRACT_TYPE  AMT_ANNUITY  AMT_APPLICATION  \
# 0     2030495      271877     Consumer loans     1730.430          17145.0
# 1     2802425      108129         Cash loans    25188.615         607500.0
# 2     2523466      122040         Cash loans    15060.735         112500.0
# 3     2819243      176158         Cash loans    47041.335         450000.0
# 4     1784265      202054         Cash loans    31924.395         337500.0
#
#    AMT_CREDIT  AMT_GOODS_PRICE NAME_CASH_LOAN_PURPOSE NAME_CONTRACT_STATUS  \
# 0     17145.0          17145.0                    XAP             Approved
# 1    679671.0         607500.0                    XNA             Approved
# 2    136444.5         112500.0                    XNA             Approved
# 3    470790.0         450000.0                    XNA             Approved
# 4    404055.0         337500.0                Repairs              Refused
#
#    DAYS_DECISION      NAME_PAYMENT_TYPE CODE_REJECT_REASON NAME_CLIENT_TYPE  \
# 0             73  Cash through the bank                XAP         Repeater
# 1            164                    XNA                XAP         Repeater
# 2            301  Cash through the bank                XAP         Repeater
# 3            512  Cash through the bank                XAP         Repeater
# 4            781  Cash through the bank                 HC         Repeater
#
#   NAME_GOODS_CATEGORY NAME_PORTFOLIO             CHANNEL_TYPE  CNT_PAYMENT  \
# 0              Mobile            POS             Country-wide         12.0
# 1                 XNA           Cash           Contact center         36.0
# 2                 XNA           Cash  Credit and cash offices         12.0
# 3                 XNA           Cash  Credit and cash offices         12.0
# 4                 XNA           Cash  Credit and cash offices         24.0
#
#   NAME_YIELD_GROUP
# 0           middle
# 1       low_action
# 2             high
# 3           middle
# 4             high

# %%
df_merged = df_1.merge(df_2, on = 'SK_ID_CURR', how = 'inner')

#  df.merge(state_df, on = "Location", how = 'left')

# %%
df_merged.shape
# Out:
# (856761, 42)

# %%
df_merged.isnull().sum()/len(df_merged) * 100
# Out:
# SK_ID_CURR                     0.0
# TARGET                         0.0
# NAME_CONTRACT_TYPE_x           0.0
# CODE_GENDER                    0.0
# FLAG_OWN_CAR                   0.0
# FLAG_OWN_REALTY                0.0
# CNT_CHILDREN                   0.0
# AMT_INCOME_TOTAL               0.0
# AMT_CREDIT_x                   0.0
# AMT_ANNUITY_x                  0.0
# AMT_GOODS_PRICE_x              0.0
# NAME_INCOME_TYPE               0.0
# NAME_EDUCATION_TYPE            0.0
# NAME_FAMILY_STATUS             0.0
# NAME_HOUSING_TYPE              0.0
# DAYS_BIRTH                     0.0
# DAYS_EMPLOYED                  0.0
# FLAG_MOBIL                     0.0
# FLAG_EMAIL                     0.0
# CNT_FAM_MEMBERS                0.0
# REGION_RATING_CLIENT           0.0
# REGION_RATING_CLIENT_W_CITY    0.0
# ORGANIZATION_TYPE              0.0
# Age                            0.0
# Years_Employed                 0.0
# SK_ID_PREV                     0.0
# NAME_CONTRACT_TYPE_y           0.0
# AMT_ANNUITY_y                  0.0
# AMT_APPLICATION                0.0
# AMT_CREDIT_y                   0.0
# AMT_GOODS_PRICE_y              0.0
# NAME_CASH_LOAN_PURPOSE         0.0
# NAME_CONTRACT_STATUS           0.0
# DAYS_DECISION                  0.0
# NAME_PAYMENT_TYPE              0.0
# CODE_REJECT_REASON             0.0
# NAME_CLIENT_TYPE               0.0
# NAME_GOODS_CATEGORY            0.0
# NAME_PORTFOLIO                 0.0
# CHANNEL_TYPE                   0.0
# CNT_PAYMENT                    0.0
# NAME_YIELD_GROUP               0.0
# dtype: float64

# %%
df_merged[df_merged.duplicated()]
# Out:
# Empty DataFrame
# Columns: [SK_ID_CURR, TARGET, NAME_CONTRACT_TYPE_x, CODE_GENDER, FLAG_OWN_CAR, FLAG_OWN_REALTY, CNT_CHILDREN, AMT_INCOME_TOTAL, AMT_CREDIT_x, AMT_ANNUITY_x, AMT_GOODS_PRICE_x, NAME_INCOME_TYPE, NAME_EDUCATION_TYPE, NAME_FAMILY_STATUS, NAME_HOUSING_TYPE, DAYS_BIRTH, DAYS_EMPLOYED, FLAG_MOBIL, FLAG_EMAIL, CNT_FAM_MEMBERS, REGION_RATING_CLIENT, REGION_RATING_CLIENT_W_CITY, ORGANIZATION_TYPE, Age, Years_Employed, SK_ID_PREV, NAME_CONTRACT_TYPE_y, AMT_ANNUITY_y, AMT_APPLICATION, AMT_CREDIT_y, AMT_GOODS_PRICE_y, NAME_CASH_LOAN_PURPOSE, NAME_CONTRACT_STATUS, DAYS_DECISION, NAME_PAYMENT_TYPE, CODE_REJECT_REASON, NAME_CLIENT_TYPE, NAME_GOODS_CATEGORY, NAME_PORTFOLIO, CHANNEL_TYPE, CNT_PAYMENT, NAME_YIELD_GROUP]
# Index: []

# %%
column_list = df_merged.columns.sort_values()

# %%
list(column_list)
# Out:
# ['AMT_ANNUITY_x',
#  'AMT_ANNUITY_y',
#  'AMT_APPLICATION',
#  'AMT_CREDIT_x',
#  'AMT_CREDIT_y',
#  'AMT_GOODS_PRICE_x',
#  'AMT_GOODS_PRICE_y',
#  'AMT_INCOME_TOTAL',
#  'Age',
#  'CHANNEL_TYPE',
#  'CNT_CHILDREN',
#  'CNT_FAM_MEMBERS',
#  'CNT_PAYMENT',
#  'CODE_GENDER',
#  'CODE_REJECT_REASON',
#  'DAYS_BIRTH',
#  'DAYS_DECISION',
#  'DAYS_EMPLOYED',
#  'FLAG_EMAIL',
#  'FLAG_MOBIL',
#  'FLAG_OWN_CAR',
#  'FLAG_OWN_REALTY',
#  'NAME_CASH_LOAN_PURPOSE',
#  'NAME_CLIENT_TYPE',
#  'NAME_CONTRACT_STATUS',
#  'NAME_CONTRACT_TYPE_x',
#  'NAME_CONTRACT_TYPE_y',
#  'NAME_EDUCATION_TYPE',
#  'NAME_FAMILY_STATUS',
#  'NAME_GOODS_CATEGORY',
#  'NAME_HOUSING_TYPE',
#  'NAME_INCOME_TYPE',
#  'NAME_PAYMENT_TYPE',
#  'NAME_PORTFOLIO',
#  'NAME_YIELD_GROUP',
#  'ORGANIZATION_TYPE',
#  'REGION_RATING_CLIENT',
#  'REGION_RATING_CLIENT_W_CITY',
#  'SK_ID_CURR',
#  'SK_ID_PREV',
#  'TARGET',
#  'Years_Employed']

# %% [markdown]
# To check if any column by chance is repeatative

# %%
for i in range(0, len(column_list)):
    count = 0
    for j in range(0, len(column_list)):
        if column_list[i] == column_list[j]:
            count += 1
        
    if count > 1:
        print(column_list[i])

# %%
df_merged.head()
# Out:
#    SK_ID_CURR TARGET NAME_CONTRACT_TYPE_x CODE_GENDER FLAG_OWN_CAR  \
# 0      100002      Y           Cash loans           M            N
# 1      100003      N           Cash loans           F            N
# 2      100003      N           Cash loans           F            N
# 3      100003      N           Cash loans           F            N
# 4      100004      N      Revolving loans           M            Y
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT_x  \
# 0               Y             0          202500.0      406597.5
# 1               N             0          270000.0     1293502.5
# 2               N             0          270000.0     1293502.5
# 3               N             0          270000.0     1293502.5
# 4               Y             0           67500.0      135000.0
#
#    AMT_ANNUITY_x  AMT_GOODS_PRICE_x NAME_INCOME_TYPE  \
# 0        24700.5           351000.0          Working
# 1        35698.5          1129500.0    State servant
# 2        35698.5          1129500.0    State servant
# 3        35698.5          1129500.0    State servant
# 4         6750.0           135000.0          Working
#
#              NAME_EDUCATION_TYPE    NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  \
# 0  Secondary / secondary special  Single / not married  House / apartment
# 1               Higher education               Married  House / apartment
# 2               Higher education               Married  House / apartment
# 3               Higher education               Married  House / apartment
# 4  Secondary / secondary special  Single / not married  House / apartment
#
#    DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  FLAG_EMAIL  CNT_FAM_MEMBERS  \
# 0       -9461           -637           1           0              1.0
# 1      -16765          -1188           1           0              2.0
# 2      -16765          -1188           1           0              2.0
# 3      -16765          -1188           1           0              2.0
# 4      -19046           -225           1           0              1.0
#
#    REGION_RATING_CLIENT  REGION_RATING_CLIENT_W_CITY       ORGANIZATION_TYPE  \
# 0                     2                            2  Business Entity Type 3
# 1                     1                            1                  School
# 2                     1                            1                  School
# 3                     1                            1                  School
# 4                     2                            2              Government
#
#    Age  Years_Employed  SK_ID_PREV NAME_CONTRACT_TYPE_y  AMT_ANNUITY_y  \
# 0   25               2     1038818       Consumer loans       9251.775
# 1   45               3     1810518           Cash loans      98356.995
# 2   45               3     2636178       Consumer loans      64567.665
# 3   45               3     2396755       Consumer loans       6737.310
# 4   52               1     1564014       Consumer loans       5357.250
#
#    AMT_APPLICATION  AMT_CREDIT_y  AMT_GOODS_PRICE_y NAME_CASH_LOAN_PURPOSE  \
# 0         179055.0      179055.0           179055.0                    XAP
# 1         900000.0     1035882.0           900000.0                    XNA
# 2         337500.0      348637.5           337500.0                    XAP
# 3          68809.5       68053.5            68809.5                    XAP
# 4          24282.0       20106.0            24282.0                    XAP
#
#   NAME_CONTRACT_STATUS  DAYS_DECISION      NAME_PAYMENT_TYPE  \
# 0             Approved            606                    XNA
# 1             Approved            746                    XNA
# 2             Approved            828  Cash through the bank
# 3             Approved           2341  Cash through the bank
# 4             Approved            815  Cash through the bank
#
#   CODE_REJECT_REASON NAME_CLIENT_TYPE   NAME_GOODS_CATEGORY NAME_PORTFOLIO  \
# 0                XAP              New              Vehicles            POS
# 1                XAP         Repeater                   XNA           Cash
# 2                XAP        Refreshed             Furniture            POS
# 3                XAP        Refreshed  Consumer Electronics            POS
# 4                XAP              New                Mobile            POS
#
#               CHANNEL_TYPE  CNT_PAYMENT NAME_YIELD_GROUP
# 0                    Stone         24.0       low_normal
# 1  Credit and cash offices         12.0       low_normal
# 2                    Stone          6.0           middle
# 3             Country-wide         12.0           middle
# 4         Regional / Local          4.0           middle

# %% [markdown]
# Droping unwanted columns

# %%
df_merged.drop(columns = ['SK_ID_CURR'], inplace = True)

# %%
df_merged.head()
# Out:
#   TARGET NAME_CONTRACT_TYPE_x CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  \
# 0      Y           Cash loans           M            N               Y
# 1      N           Cash loans           F            N               N
# 2      N           Cash loans           F            N               N
# 3      N           Cash loans           F            N               N
# 4      N      Revolving loans           M            Y               Y
#
#    CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT_x  AMT_ANNUITY_x  \
# 0             0          202500.0      406597.5        24700.5
# 1             0          270000.0     1293502.5        35698.5
# 2             0          270000.0     1293502.5        35698.5
# 3             0          270000.0     1293502.5        35698.5
# 4             0           67500.0      135000.0         6750.0
#
#    AMT_GOODS_PRICE_x NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0           351000.0          Working  Secondary / secondary special
# 1          1129500.0    State servant               Higher education
# 2          1129500.0    State servant               Higher education
# 3          1129500.0    State servant               Higher education
# 4           135000.0          Working  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0  Single / not married  House / apartment       -9461           -637
# 1               Married  House / apartment      -16765          -1188
# 2               Married  House / apartment      -16765          -1188
# 3               Married  House / apartment      -16765          -1188
# 4  Single / not married  House / apartment      -19046           -225
#
#    FLAG_MOBIL  FLAG_EMAIL  CNT_FAM_MEMBERS  REGION_RATING_CLIENT  \
# 0           1           0              1.0                     2
# 1           1           0              2.0                     1
# 2           1           0              2.0                     1
# 3           1           0              2.0                     1
# 4           1           0              1.0                     2
#
#    REGION_RATING_CLIENT_W_CITY       ORGANIZATION_TYPE  Age  Years_Employed  \
# 0                            2  Business Entity Type 3   25               2
# 1                            1                  School   45               3
# 2                            1                  School   45               3
# 3                            1                  School   45               3
# 4                            2              Government   52               1
#
#    SK_ID_PREV NAME_CONTRACT_TYPE_y  AMT_ANNUITY_y  AMT_APPLICATION  \
# 0     1038818       Consumer loans       9251.775         179055.0
# 1     1810518           Cash loans      98356.995         900000.0
# 2     2636178       Consumer loans      64567.665         337500.0
# 3     2396755       Consumer loans       6737.310          68809.5
# 4     1564014       Consumer loans       5357.250          24282.0
#
#    AMT_CREDIT_y  AMT_GOODS_PRICE_y NAME_CASH_LOAN_PURPOSE  \
# 0      179055.0           179055.0                    XAP
# 1     1035882.0           900000.0                    XNA
# 2      348637.5           337500.0                    XAP
# 3       68053.5            68809.5                    XAP
# 4       20106.0            24282.0                    XAP
#
#   NAME_CONTRACT_STATUS  DAYS_DECISION      NAME_PAYMENT_TYPE  \
# 0             Approved            606                    XNA
# 1             Approved            746                    XNA
# 2             Approved            828  Cash through the bank
# 3             Approved           2341  Cash through the bank
# 4             Approved            815  Cash through the bank
#
#   CODE_REJECT_REASON NAME_CLIENT_TYPE   NAME_GOODS_CATEGORY NAME_PORTFOLIO  \
# 0                XAP              New              Vehicles            POS
# 1                XAP         Repeater                   XNA           Cash
# 2                XAP        Refreshed             Furniture            POS
# 3                XAP        Refreshed  Consumer Electronics            POS
# 4                XAP              New                Mobile            POS
#
#               CHANNEL_TYPE  CNT_PAYMENT NAME_YIELD_GROUP
# 0                    Stone         24.0       low_normal
# 1  Credit and cash offices         12.0       low_normal
# 2                    Stone          6.0           middle
# 3             Country-wide         12.0           middle
# 4         Regional / Local          4.0           middle

# %%
plt.pie(df_merged.TARGET.value_counts(),
       labels = df_merged.TARGET.value_counts().index, 
       autopct = '%1.01f%%')

plt.show()

# %%
df_merged.reindex(sorted(df_merged.columns), axis=1)
# Out:
#         AMT_ANNUITY_x  AMT_ANNUITY_y  AMT_APPLICATION  AMT_CREDIT_x  \
# 0             24700.5       9251.775         179055.0      406597.5
# 1             35698.5      98356.995         900000.0     1293502.5
# 2             35698.5      64567.665         337500.0     1293502.5
# 3             35698.5       6737.310          68809.5     1293502.5
# 4              6750.0       5357.250          24282.0      135000.0
# ...               ...            ...              ...           ...
# 856756        49117.5      16400.610         229500.0      675000.0
# 856757        49117.5       2250.000          45000.0      675000.0
# 856758        49117.5      30737.655         765000.0      675000.0
# 856759        49117.5      54022.140        1170000.0      675000.0
# 856760        49117.5      11514.555          58225.5      675000.0
#
#         AMT_CREDIT_y  AMT_GOODS_PRICE_x  AMT_GOODS_PRICE_y  AMT_INCOME_TOTAL  \
# 0           179055.0           351000.0           179055.0          202500.0
# 1          1035882.0          1129500.0           900000.0          270000.0
# 2           348637.5          1129500.0           337500.0          270000.0
# 3            68053.5          1129500.0            68809.5          270000.0
# 4            20106.0           135000.0            24282.0           67500.0
# ...              ...                ...                ...               ...
# 856756      254340.0           675000.0           229500.0          157500.0
# 856757       45000.0           675000.0            45000.0          157500.0
# 856758     1067940.0           675000.0           765000.0          157500.0
# 856759     1271929.5           675000.0          1170000.0          157500.0
# 856760       58545.0           675000.0            58225.5          157500.0
#
#         Age             CHANNEL_TYPE  CNT_CHILDREN  CNT_FAM_MEMBERS  \
# 0        25                    Stone             0              1.0
# 1        45  Credit and cash offices             0              2.0
# 2        45                    Stone             0              2.0
# 3        45             Country-wide             0              2.0
# 4        52         Regional / Local             0              1.0
# ...     ...                      ...           ...              ...
# 856756   46  Credit and cash offices             0              2.0
# 856757   46             Country-wide             0              2.0
# 856758   46  Credit and cash offices             0              2.0
# 856759   46          AP+ (Cash loan)             0              2.0
# 856760   46             Country-wide             0              2.0
#
#         CNT_PAYMENT CODE_GENDER CODE_REJECT_REASON  DAYS_BIRTH  DAYS_DECISION  \
# 0              24.0           M                XAP       -9461            606
# 1              12.0           F                XAP      -16765            746
# 2               6.0           F                XAP      -16765            828
# 3              12.0           F                XAP      -16765           2341
# 4               4.0           M                XAP      -19046            815
# ...             ...         ...                ...         ...            ...
# 856756         24.0           F                XAP      -16856            648
# 856757          0.0           F                 HC      -16856            456
# 856758         60.0           F                 HC      -16856            171
# 856759         36.0           F                XAP      -16856            787
# 856760          6.0           F                XAP      -16856            500
#
#         DAYS_EMPLOYED  FLAG_EMAIL  FLAG_MOBIL FLAG_OWN_CAR FLAG_OWN_REALTY  \
# 0                -637           0           1            N               Y
# 1               -1188           0           1            N               N
# 2               -1188           0           1            N               N
# 3               -1188           0           1            N               N
# 4                -225           0           1            Y               Y
# ...               ...         ...         ...          ...             ...
# 856756          -1262           0           1            N               N
# 856757          -1262           0           1            N               N
# 856758          -1262           0           1            N               N
# 856759          -1262           0           1            N               N
# 856760          -1262           0           1            N               N
#
#        NAME_CASH_LOAN_PURPOSE NAME_CLIENT_TYPE NAME_CONTRACT_STATUS  \
# 0                         XAP              New             Approved
# 1                         XNA         Repeater             Approved
# 2                         XAP        Refreshed             Approved
# 3                         XAP        Refreshed             Approved
# 4                         XAP              New             Approved
# ...                       ...              ...                  ...
# 856756                    XNA         Repeater             Approved
# 856757                    XAP         Repeater              Refused
# 856758                Repairs         Repeater              Refused
# 856759                    XNA         Repeater             Approved
# 856760                    XAP         Repeater             Approved
#
#        NAME_CONTRACT_TYPE_x NAME_CONTRACT_TYPE_y  \
# 0                Cash loans       Consumer loans
# 1                Cash loans           Cash loans
# 2                Cash loans       Consumer loans
# 3                Cash loans       Consumer loans
# 4           Revolving loans       Consumer loans
# ...                     ...                  ...
# 856756           Cash loans           Cash loans
# 856757           Cash loans      Revolving loans
# 856758           Cash loans           Cash loans
# 856759           Cash loans           Cash loans
# 856760           Cash loans       Consumer loans
#
#                   NAME_EDUCATION_TYPE    NAME_FAMILY_STATUS  \
# 0       Secondary / secondary special  Single / not married
# 1                    Higher education               Married
# 2                    Higher education               Married
# 3                    Higher education               Married
# 4       Secondary / secondary special  Single / not married
# ...                               ...                   ...
# 856756               Higher education               Married
# 856757               Higher education               Married
# 856758               Higher education               Married
# 856759               Higher education               Married
# 856760               Higher education               Married
#
#          NAME_GOODS_CATEGORY  NAME_HOUSING_TYPE      NAME_INCOME_TYPE  \
# 0                   Vehicles  House / apartment               Working
# 1                        XNA  House / apartment         State servant
# 2                  Furniture  House / apartment         State servant
# 3       Consumer Electronics  House / apartment         State servant
# 4                     Mobile  House / apartment               Working
# ...                      ...                ...                   ...
# 856756                   XNA  House / apartment  Commercial associate
# 856757                   XNA  House / apartment  Commercial associate
# 856758                   XNA  House / apartment  Commercial associate
# 856759                   XNA  House / apartment  Commercial associate
# 856760             Computers  House / apartment  Commercial associate
#
#             NAME_PAYMENT_TYPE NAME_PORTFOLIO NAME_YIELD_GROUP  \
# 0                         XNA            POS       low_normal
# 1                         XNA           Cash       low_normal
# 2       Cash through the bank            POS           middle
# 3       Cash through the bank            POS           middle
# 4       Cash through the bank            POS           middle
# ...                       ...            ...              ...
# 856756  Cash through the bank           Cash           middle
# 856757                    XNA          Cards              XNA
# 856758  Cash through the bank           Cash       low_normal
# 856759  Cash through the bank           Cash       low_normal
# 856760  Cash through the bank            POS             high
#
#              ORGANIZATION_TYPE  REGION_RATING_CLIENT  \
# 0       Business Entity Type 3                     2
# 1                       School                     1
# 2                       School                     1
# 3                       School                     1
# 4                   Government                     2
# ...                        ...                   ...
# 856756  Business Entity Type 3                     1
# 856757  Business Entity Type 3                     1
# 856758  Business Entity Type 3                     1
# 856759  Business Entity Type 3                     1
# 856760  Business Entity Type 3                     1
#
#         REGION_RATING_CLIENT_W_CITY  SK_ID_PREV TARGET  Years_Employed
# 0                                 2     1038818      Y               2
# 1                                 1     1810518      N               3
# 2                                 1     2636178      N               3
# 3                                 1     2396755      N               3
# 4                                 2     1564014      N               1
# ...                             ...         ...    ...             ...
# 856756                            1     2073384      N               4
# 856757                            1     1708056      N               4
# 856758                            1     1296007      N               4
# 856759                            1     2631384      N               4
# 856760                            1     2729207      N               4
#
# [856761 rows x 41 columns]

# %% [markdown]
# The columns which are present in the x datasheet and also in the y datasheet, let's compare them to understand more.
#
# - `AMT_ANNUITY`: Change in Annuity of present datasheet compared to previous

# %%
df_annuity = df_merged[['AMT_ANNUITY_x', 'AMT_ANNUITY_y']]

# %%
df_annuity['change_annuity_percent'] = df_annuity['AMT_ANNUITY_x']/df_annuity['AMT_ANNUITY_y']*100 - 100

# %%
df_annuity
# Out:
#         AMT_ANNUITY_x  AMT_ANNUITY_y  change_annuity_percent
# 0             24700.5       9251.775              166.981201
# 1             35698.5      98356.995              -63.705174
# 2             35698.5      64567.665              -44.711490
# 3             35698.5       6737.310              429.862809
# 4              6750.0       5357.250               25.997480
# ...               ...            ...                     ...
# 856756        49117.5      16400.610              199.485812
# 856757        49117.5       2250.000             2083.000000
# 856758        49117.5      30737.655               59.795860
# 856759        49117.5      54022.140               -9.078944
# 856760        49117.5      11514.555              326.568808
#
# [856761 rows x 3 columns]

# %%
df_annuity.change_annuity_percent.sort_values()
# Out:
# 502380   -96.089346
# 43344    -95.818725
# 402296   -95.797569
# 526056   -95.138353
# 552876   -95.111775
#             ...
# 7871            inf
# 317442          inf
# 665797          inf
# 568529          inf
# 129917          inf
# Name: change_annuity_percent, Length: 856761, dtype: float64

# %%
df_annuity[df_annuity.change_annuity_percent == np.inf]
# Out:
#         AMT_ANNUITY_x  AMT_ANNUITY_y  change_annuity_percent
# 2652          25744.5            0.0                     inf
# 2653          25744.5            0.0                     inf
# 2654          25744.5            0.0                     inf
# 2981          15228.0            0.0                     inf
# 4009          39645.0            0.0                     inf
# ...               ...            ...                     ...
# 854031        36184.5            0.0                     inf
# 854235        14436.0            0.0                     inf
# 854251        32643.0            0.0                     inf
# 854681        15255.0            0.0                     inf
# 855360        20133.0            0.0                     inf
#
# [812 rows x 3 columns]

# %%
df_annuity.iloc[7871, :]
# Out:
# AMT_ANNUITY_x             11709.0
# AMT_ANNUITY_y                 0.0
# change_annuity_percent        inf
# Name: 7871, dtype: float64

# %%
df_annuity.change_annuity_percent.describe()
# Out:
# count    8.567610e+05
# mean              inf
# std               NaN
# min     -9.608935e+01
# 25%      1.325858e+01
# 50%      1.155735e+02
# 75%      3.134454e+02
# max               inf
# Name: change_annuity_percent, dtype: float64

# %%
plt.figure(figsize = (12, 5))
sns.boxplot(df_annuity.change_annuity_percent, color = 'orange')

plt.show()

# %% [markdown]
# - `AMT_CREDIT`

# %%
df_merged.head()
# Out:
#   TARGET NAME_CONTRACT_TYPE_x CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  \
# 0      Y           Cash loans           M            N               Y
# 1      N           Cash loans           F            N               N
# 2      N           Cash loans           F            N               N
# 3      N           Cash loans           F            N               N
# 4      N      Revolving loans           M            Y               Y
#
#    CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT_x  AMT_ANNUITY_x  \
# 0             0          202500.0      406597.5        24700.5
# 1             0          270000.0     1293502.5        35698.5
# 2             0          270000.0     1293502.5        35698.5
# 3             0          270000.0     1293502.5        35698.5
# 4             0           67500.0      135000.0         6750.0
#
#    AMT_GOODS_PRICE_x NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0           351000.0          Working  Secondary / secondary special
# 1          1129500.0    State servant               Higher education
# 2          1129500.0    State servant               Higher education
# 3          1129500.0    State servant               Higher education
# 4           135000.0          Working  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0  Single / not married  House / apartment       -9461           -637
# 1               Married  House / apartment      -16765          -1188
# 2               Married  House / apartment      -16765          -1188
# 3               Married  House / apartment      -16765          -1188
# 4  Single / not married  House / apartment      -19046           -225
#
#    FLAG_MOBIL  FLAG_EMAIL  CNT_FAM_MEMBERS  REGION_RATING_CLIENT  \
# 0           1           0              1.0                     2
# 1           1           0              2.0                     1
# 2           1           0              2.0                     1
# 3           1           0              2.0                     1
# 4           1           0              1.0                     2
#
#    REGION_RATING_CLIENT_W_CITY       ORGANIZATION_TYPE  Age  Years_Employed  \
# 0                            2  Business Entity Type 3   25               2
# 1                            1                  School   45               3
# 2                            1                  School   45               3
# 3                            1                  School   45               3
# 4                            2              Government   52               1
#
#    SK_ID_PREV NAME_CONTRACT_TYPE_y  AMT_ANNUITY_y  AMT_APPLICATION  \
# 0     1038818       Consumer loans       9251.775         179055.0
# 1     1810518           Cash loans      98356.995         900000.0
# 2     2636178       Consumer loans      64567.665         337500.0
# 3     2396755       Consumer loans       6737.310          68809.5
# 4     1564014       Consumer loans       5357.250          24282.0
#
#    AMT_CREDIT_y  AMT_GOODS_PRICE_y NAME_CASH_LOAN_PURPOSE  \
# 0      179055.0           179055.0                    XAP
# 1     1035882.0           900000.0                    XNA
# 2      348637.5           337500.0                    XAP
# 3       68053.5            68809.5                    XAP
# 4       20106.0            24282.0                    XAP
#
#   NAME_CONTRACT_STATUS  DAYS_DECISION      NAME_PAYMENT_TYPE  \
# 0             Approved            606                    XNA
# 1             Approved            746                    XNA
# 2             Approved            828  Cash through the bank
# 3             Approved           2341  Cash through the bank
# 4             Approved            815  Cash through the bank
#
#   CODE_REJECT_REASON NAME_CLIENT_TYPE   NAME_GOODS_CATEGORY NAME_PORTFOLIO  \
# 0                XAP              New              Vehicles            POS
# 1                XAP         Repeater                   XNA           Cash
# 2                XAP        Refreshed             Furniture            POS
# 3                XAP        Refreshed  Consumer Electronics            POS
# 4                XAP              New                Mobile            POS
#
#               CHANNEL_TYPE  CNT_PAYMENT NAME_YIELD_GROUP
# 0                    Stone         24.0       low_normal
# 1  Credit and cash offices         12.0       low_normal
# 2                    Stone          6.0           middle
# 3             Country-wide         12.0           middle
# 4         Regional / Local          4.0           middle

# %%
amt_credit = df_merged[['AMT_CREDIT_x', 'AMT_CREDIT_y']]

# %%
amt_credit.head()
# Out:
#    AMT_CREDIT_x  AMT_CREDIT_y
# 0      406597.5      179055.0
# 1     1293502.5     1035882.0
# 2     1293502.5      348637.5
# 3     1293502.5       68053.5
# 4      135000.0       20106.0

# %%
amt_credit['change_percent'] = amt_credit['AMT_CREDIT_x']/amt_credit['AMT_CREDIT_y'] * 100 - 100

# %%
amt_credit['change_percent'][amt_credit['change_percent'] == np.inf]
# Out:
# 2652      inf
# 2653      inf
# 2654      inf
# 2981      inf
# 4009      inf
#          ...
# 854031    inf
# 854235    inf
# 854251    inf
# 854681    inf
# 855360    inf
# Name: change_percent, Length: 811, dtype: float64

# %%
amt_credit[amt_credit['change_percent'] != np.inf]
# Out:
#         AMT_CREDIT_x  AMT_CREDIT_y  change_percent
# 0           406597.5      179055.0      127.079668
# 1          1293502.5     1035882.0       24.869676
# 2          1293502.5      348637.5      271.016457
# 3          1293502.5       68053.5     1800.714144
# 4           135000.0       20106.0      571.441361
# ...              ...           ...             ...
# 856756      675000.0      254340.0      165.392781
# 856757      675000.0       45000.0     1400.000000
# 856758      675000.0     1067940.0      -36.794202
# 856759      675000.0     1271929.5      -46.931021
# 856760      675000.0       58545.0     1052.959262
#
# [855950 rows x 3 columns]

# %%
plt.figure(figsize = (12, 5))
sns.boxplot(amt_credit.change_percent[amt_credit['change_percent'] != np.inf])

plt.show()

# %%
amt_credit.iloc[2652, :]
# Out:
# AMT_CREDIT_x      324216.0
# AMT_CREDIT_y           0.0
# change_percent         inf
# Name: 2652, dtype: float64

# %% [markdown]
# - `AMT_GOODS_PRICE`

# %%
df_merged[['AMT_GOODS_PRICE_x', 'AMT_GOODS_PRICE_y']]
# Out:
#         AMT_GOODS_PRICE_x  AMT_GOODS_PRICE_y
# 0                351000.0           179055.0
# 1               1129500.0           900000.0
# 2               1129500.0           337500.0
# 3               1129500.0            68809.5
# 4                135000.0            24282.0
# ...                   ...                ...
# 856756           675000.0           229500.0
# 856757           675000.0            45000.0
# 856758           675000.0           765000.0
# 856759           675000.0          1170000.0
# 856760           675000.0            58225.5
#
# [856761 rows x 2 columns]

# %%
goods_price = df_merged[['AMT_GOODS_PRICE_x', 'AMT_GOODS_PRICE_y']]
goods_price['change_good_percent'] = goods_price['AMT_GOODS_PRICE_x']/goods_price['AMT_GOODS_PRICE_y']*100 - 100
goods_price.head()
# Out:
#    AMT_GOODS_PRICE_x  AMT_GOODS_PRICE_y  change_good_percent
# 0           351000.0           179055.0            96.029153
# 1          1129500.0           900000.0            25.500000
# 2          1129500.0           337500.0           234.666667
# 3          1129500.0            68809.5          1541.488457
# 4           135000.0            24282.0           455.967383

# %%
goods_price[goods_price['change_good_percent'] != np.inf]
# Out:
#         AMT_GOODS_PRICE_x  AMT_GOODS_PRICE_y  change_good_percent
# 0                351000.0           179055.0            96.029153
# 1               1129500.0           900000.0            25.500000
# 2               1129500.0           337500.0           234.666667
# 3               1129500.0            68809.5          1541.488457
# 4                135000.0            24282.0           455.967383
# ...                   ...                ...                  ...
# 856756           675000.0           229500.0           194.117647
# 856757           675000.0            45000.0          1400.000000
# 856758           675000.0           765000.0           -11.764706
# 856759           675000.0          1170000.0           -42.307692
# 856760           675000.0            58225.5          1059.285880
#
# [852848 rows x 3 columns]

# %%
plt.figure(figsize = (12, 5))
sns.boxplot(goods_price.change_good_percent[goods_price['change_good_percent'] != np.inf])

plt.show()

# %%
goods_price.change_good_percent[goods_price['change_good_percent'] != np.inf].min()
# Out:
# -98.0

# %% [markdown]
# - `NAME_CONTRACT_TYPE`

# %%
df_merged.head()
# Out:
#   TARGET NAME_CONTRACT_TYPE_x CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  \
# 0      Y           Cash loans           M            N               Y
# 1      N           Cash loans           F            N               N
# 2      N           Cash loans           F            N               N
# 3      N           Cash loans           F            N               N
# 4      N      Revolving loans           M            Y               Y
#
#    CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT_x  AMT_ANNUITY_x  \
# 0             0          202500.0      406597.5        24700.5
# 1             0          270000.0     1293502.5        35698.5
# 2             0          270000.0     1293502.5        35698.5
# 3             0          270000.0     1293502.5        35698.5
# 4             0           67500.0      135000.0         6750.0
#
#    AMT_GOODS_PRICE_x NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0           351000.0          Working  Secondary / secondary special
# 1          1129500.0    State servant               Higher education
# 2          1129500.0    State servant               Higher education
# 3          1129500.0    State servant               Higher education
# 4           135000.0          Working  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0  Single / not married  House / apartment       -9461           -637
# 1               Married  House / apartment      -16765          -1188
# 2               Married  House / apartment      -16765          -1188
# 3               Married  House / apartment      -16765          -1188
# 4  Single / not married  House / apartment      -19046           -225
#
#    FLAG_MOBIL  FLAG_EMAIL  CNT_FAM_MEMBERS  REGION_RATING_CLIENT  \
# 0           1           0              1.0                     2
# 1           1           0              2.0                     1
# 2           1           0              2.0                     1
# 3           1           0              2.0                     1
# 4           1           0              1.0                     2
#
#    REGION_RATING_CLIENT_W_CITY       ORGANIZATION_TYPE  Age  Years_Employed  \
# 0                            2  Business Entity Type 3   25               2
# 1                            1                  School   45               3
# 2                            1                  School   45               3
# 3                            1                  School   45               3
# 4                            2              Government   52               1
#
#    SK_ID_PREV NAME_CONTRACT_TYPE_y  AMT_ANNUITY_y  AMT_APPLICATION  \
# 0     1038818       Consumer loans       9251.775         179055.0
# 1     1810518           Cash loans      98356.995         900000.0
# 2     2636178       Consumer loans      64567.665         337500.0
# 3     2396755       Consumer loans       6737.310          68809.5
# 4     1564014       Consumer loans       5357.250          24282.0
#
#    AMT_CREDIT_y  AMT_GOODS_PRICE_y NAME_CASH_LOAN_PURPOSE  \
# 0      179055.0           179055.0                    XAP
# 1     1035882.0           900000.0                    XNA
# 2      348637.5           337500.0                    XAP
# 3       68053.5            68809.5                    XAP
# 4       20106.0            24282.0                    XAP
#
#   NAME_CONTRACT_STATUS  DAYS_DECISION      NAME_PAYMENT_TYPE  \
# 0             Approved            606                    XNA
# 1             Approved            746                    XNA
# 2             Approved            828  Cash through the bank
# 3             Approved           2341  Cash through the bank
# 4             Approved            815  Cash through the bank
#
#   CODE_REJECT_REASON NAME_CLIENT_TYPE   NAME_GOODS_CATEGORY NAME_PORTFOLIO  \
# 0                XAP              New              Vehicles            POS
# 1                XAP         Repeater                   XNA           Cash
# 2                XAP        Refreshed             Furniture            POS
# 3                XAP        Refreshed  Consumer Electronics            POS
# 4                XAP              New                Mobile            POS
#
#               CHANNEL_TYPE  CNT_PAYMENT NAME_YIELD_GROUP
# 0                    Stone         24.0       low_normal
# 1  Credit and cash offices         12.0       low_normal
# 2                    Stone          6.0           middle
# 3             Country-wide         12.0           middle
# 4         Regional / Local          4.0           middle

# %%
sns.countplot(df_merged.NAME_CONTRACT_TYPE_x)
# Out:
# <AxesSubplot:xlabel='NAME_CONTRACT_TYPE_x', ylabel='count'>

# %%
sns.countplot(df_merged.NAME_CONTRACT_TYPE_y)
# Out:
# <AxesSubplot:xlabel='NAME_CONTRACT_TYPE_y', ylabel='count'>

# %%
df_merged.NAME_CONTRACT_TYPE_y.value_counts()
# Out:
# Consumer loans     497273
# Cash loans         292825
# Revolving loans     66663
# Name: NAME_CONTRACT_TYPE_y, dtype: int64

# %%
df_merged.NAME_CONTRACT_TYPE_x.value_counts()
# Out:
# Cash loans         785612
# Revolving loans     71149
# Name: NAME_CONTRACT_TYPE_x, dtype: int64

# %% [markdown]
# How many people switched their contract type?

# %%
df_merged[(df_merged.NAME_CONTRACT_TYPE_y !=  df_merged.NAME_CONTRACT_TYPE_x)].shape[0]
# Out:
# 578389

# %% [markdown]
# How many people stayed on their same contract?

# %%
df_merged[(df_merged.NAME_CONTRACT_TYPE_y ==  df_merged.NAME_CONTRACT_TYPE_x)].shape[0]
# Out:
# 278372

# %% [markdown]
# % of change in contract

# %%
round(578389/len(df_merged) * 100, 2)
# Out:
# 67.51

# %% [markdown]
# ## Heading 1

# %%
df_merged.head()
# Out:
#   TARGET NAME_CONTRACT_TYPE_x CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  \
# 0      Y           Cash loans           M            N               Y
# 1      N           Cash loans           F            N               N
# 2      N           Cash loans           F            N               N
# 3      N           Cash loans           F            N               N
# 4      N      Revolving loans           M            Y               Y
#
#    CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT_x  AMT_ANNUITY_x  \
# 0             0          202500.0      406597.5        24700.5
# 1             0          270000.0     1293502.5        35698.5
# 2             0          270000.0     1293502.5        35698.5
# 3             0          270000.0     1293502.5        35698.5
# 4             0           67500.0      135000.0         6750.0
#
#    AMT_GOODS_PRICE_x NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0           351000.0          Working  Secondary / secondary special
# 1          1129500.0    State servant               Higher education
# 2          1129500.0    State servant               Higher education
# 3          1129500.0    State servant               Higher education
# 4           135000.0          Working  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0  Single / not married  House / apartment       -9461           -637
# 1               Married  House / apartment      -16765          -1188
# 2               Married  House / apartment      -16765          -1188
# 3               Married  House / apartment      -16765          -1188
# 4  Single / not married  House / apartment      -19046           -225
#
#    FLAG_MOBIL  FLAG_EMAIL  CNT_FAM_MEMBERS  REGION_RATING_CLIENT  \
# 0           1           0              1.0                     2
# 1           1           0              2.0                     1
# 2           1           0              2.0                     1
# 3           1           0              2.0                     1
# 4           1           0              1.0                     2
#
#    REGION_RATING_CLIENT_W_CITY       ORGANIZATION_TYPE  Age  Years_Employed  \
# 0                            2  Business Entity Type 3   25               2
# 1                            1                  School   45               3
# 2                            1                  School   45               3
# 3                            1                  School   45               3
# 4                            2              Government   52               1
#
#    SK_ID_PREV NAME_CONTRACT_TYPE_y  AMT_ANNUITY_y  AMT_APPLICATION  \
# 0     1038818       Consumer loans       9251.775         179055.0
# 1     1810518           Cash loans      98356.995         900000.0
# 2     2636178       Consumer loans      64567.665         337500.0
# 3     2396755       Consumer loans       6737.310          68809.5
# 4     1564014       Consumer loans       5357.250          24282.0
#
#    AMT_CREDIT_y  AMT_GOODS_PRICE_y NAME_CASH_LOAN_PURPOSE  \
# 0      179055.0           179055.0                    XAP
# 1     1035882.0           900000.0                    XNA
# 2      348637.5           337500.0                    XAP
# 3       68053.5            68809.5                    XAP
# 4       20106.0            24282.0                    XAP
#
#   NAME_CONTRACT_STATUS  DAYS_DECISION      NAME_PAYMENT_TYPE  \
# 0             Approved            606                    XNA
# 1             Approved            746                    XNA
# 2             Approved            828  Cash through the bank
# 3             Approved           2341  Cash through the bank
# 4             Approved            815  Cash through the bank
#
#   CODE_REJECT_REASON NAME_CLIENT_TYPE   NAME_GOODS_CATEGORY NAME_PORTFOLIO  \
# 0                XAP              New              Vehicles            POS
# 1                XAP         Repeater                   XNA           Cash
# 2                XAP        Refreshed             Furniture            POS
# 3                XAP        Refreshed  Consumer Electronics            POS
# 4                XAP              New                Mobile            POS
#
#               CHANNEL_TYPE  CNT_PAYMENT NAME_YIELD_GROUP
# 0                    Stone         24.0       low_normal
# 1  Credit and cash offices         12.0       low_normal
# 2                    Stone          6.0           middle
# 3             Country-wide         12.0           middle
# 4         Regional / Local          4.0           middle

# %% [markdown]
# - `CODE_GENDER`: Analysing the data based on Gender

# %%
plt.figure(figsize = (12, 5))
sns.scatterplot(df_merged.AMT_INCOME_TOTAL,df_merged.DAYS_DECISION, hue = df_merged.CODE_GENDER[df_merged.CODE_GENDER =="M"])

plt.show()

# %%
plt.figure(figsize = (12, 5))
sns.scatterplot(df_merged.AMT_INCOME_TOTAL,df_merged.DAYS_DECISION, hue = df_merged.CODE_GENDER[df_merged.CODE_GENDER =="F"])

plt.show()

# %%
plt.figure(figsize = (12, 6))
sns.boxplot(df_merged.AMT_INCOME_TOTAL, df_merged.CODE_GENDER)

plt.show()

# %%
plt.figure(figsize = (12, 6))
sns.boxplot(df_merged.CNT_PAYMENT,df_merged.CODE_GENDER )
plt.show()

# %%
sns.boxplot(df_merged.DAYS_DECISION,df_merged.CODE_GENDER )
# Out:
# <AxesSubplot:xlabel='DAYS_DECISION', ylabel='CODE_GENDER'>

# %%
sns.boxplot(df_merged.AMT_CREDIT_x,df_merged.CODE_GENDER )
# Out:
# <AxesSubplot:xlabel='AMT_CREDIT_x', ylabel='CODE_GENDER'>

# %%
plt.figure(figsize = (12, 7))
sns.barplot(df_merged.AMT_INCOME_TOTAL, df_merged.NAME_INCOME_TYPE,hue = df_merged.CODE_GENDER )

plt.show()

# %%
plt.figure(figsize = (12, 7))
sns.barplot(df_merged.AMT_INCOME_TOTAL, df_merged.NAME_EDUCATION_TYPE, hue = df_merged.CODE_GENDER )

plt.show()

# %%
plt.figure(figsize = (12, 20))
sns.barplot(df_merged.AMT_INCOME_TOTAL, df_merged.ORGANIZATION_TYPE, hue = df_merged.CODE_GENDER )

plt.show()

# %%
sns.boxplot(df_merged.Age, df_merged.CODE_GENDER)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='CODE_GENDER'>

# %%
sns.boxplot(df_merged.Years_Employed, df_merged.CODE_GENDER)
# Out:
# <AxesSubplot:xlabel='Years_Employed', ylabel='CODE_GENDER'>

# %%
plt.figure(figsize = (12, 6))
sns.barplot(df_merged.AMT_CREDIT_x, df_merged.NAME_CONTRACT_STATUS, hue = df_merged.CODE_GENDER )

plt.show()

# %%
plt.figure(figsize = (12, 6))
sns.barplot(df_merged.AMT_CREDIT_y, df_merged.NAME_CONTRACT_STATUS, hue = df_merged.CODE_GENDER )

plt.show()

# %%
plt.figure(figsize = (12, 6))
sns.barplot(df_merged.AMT_INCOME_TOTAL, df_merged.NAME_CONTRACT_STATUS, hue = df_merged.CODE_GENDER )

plt.show()

# %% [markdown]
# Which type of Contract Type is profitable?

# %%
plt.figure(figsize = (12, 6))
sns.barplot(df_merged.AMT_INCOME_TOTAL, df_merged.NAME_CONTRACT_TYPE_x, hue = df_merged.CODE_GENDER )

plt.show()

# %%
plt.figure(figsize = (12, 6))
sns.barplot(df_merged.AMT_INCOME_TOTAL, df_merged.NAME_CONTRACT_TYPE_y, hue = df_merged.CODE_GENDER )

plt.show()

# %%
plt.figure(figsize = (12, 6))
sns.barplot(df_merged.AMT_CREDIT_x, df_merged.NAME_INCOME_TYPE, hue = df_merged.CODE_GENDER )

plt.show()

# %%
plt.figure(figsize = (12, 6))
sns.barplot(df_merged.AMT_CREDIT_y, df_merged.NAME_INCOME_TYPE, hue = df_merged.CODE_GENDER )

plt.show()

# %%
plt.figure(figsize = (12, 6))
sns.barplot(df_merged.AMT_CREDIT_x, df_merged.NAME_HOUSING_TYPE, hue = df_merged.CODE_GENDER )

plt.show()

# %%
plt.figure(figsize = (12, 6))
sns.barplot(df_merged.AMT_CREDIT_y, df_merged.NAME_HOUSING_TYPE, hue = df_merged.CODE_GENDER )

plt.show()

# %%
plt.figure(figsize = (12, 17))
sns.barplot(df_merged.AMT_APPLICATION, df_merged.ORGANIZATION_TYPE, hue = df_merged.CODE_GENDER )

plt.show()

# %%
plt.figure(figsize = (12, 17))
sns.barplot(df_merged.AMT_APPLICATION, df_merged.NAME_CONTRACT_STATUS, hue = df_merged.CODE_GENDER )

plt.show()

# %%
plt.figure(figsize = (12, 17))
sns.barplot(df_merged.AMT_APPLICATION, df_merged.CHANNEL_TYPE, hue = df_merged.CODE_GENDER )

plt.show()

# %%
plt.figure(figsize = (12, 8))
sns.heatmap(round(df_merged.corr(), 2), annot = True)
plt.show()

# %%
plt.figure(figsize = (12, 5))
sns.scatterplot(df_merged.DAYS_DECISION, df_merged.AMT_APPLICATION)

plt.show()

# %%
df_merged.DAYS_DECISION.describe()
# Out:
# count    856761.000000
# mean       1020.506997
# std         787.323106
# min           1.000000
# 25%         382.000000
# 50%         762.000000
# 75%        1540.000000
# max        2922.000000
# Name: DAYS_DECISION, dtype: float64
