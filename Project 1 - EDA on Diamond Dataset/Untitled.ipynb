# %%
# importing necessary libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
diamond_df = pd.read_csv('diamonds.csv')
diamond_df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
diamond_df.shape
# Out:
# (53940, 11)

# %%
diamond_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53940 non-null  int64
#  1   carat       53940 non-null  float64
#  2   cut         53940 non-null  object
#  3   color       53940 non-null  object
#  4   clarity     53940 non-null  object
#  5   depth       53940 non-null  float64
#  6   table       53940 non-null  float64
#  7   price       53940 non-null  int64
#  8   x           53940 non-null  float64
#  9   y           53940 non-null  float64
#  10  z           53940 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.5+ MB

# %%
diamond_df[diamond_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, carat, cut, color, clarity, depth, table, price, x, y, z]
# Index: []

# %%
diamond_df.drop(columns = ['Unnamed: 0'], inplace = True)

# %%
diamond_df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
diamond_df.color.unique()
# Out:
# array(['E', 'I', 'J', 'H', 'F', 'G', 'D'], dtype=object)

# %%
# diamond_df['Color Desp'] = diamond_df.color.apply(lambda x: "Colourless" if (x =='D') | (x == 'E') | (x == 'F') 
#                                                 else ('Near Colourless' if (x == 'G')|(x == 'H')|(x == 'I')|(x == 'J') 
#                                                 else ('Faint' if (x == 'K')|(x == 'L')|(x == 'M') 
#                                                 else ('Very Light Yellow' if ((x == 'N')|(x == 'O')|(x == 'P')|(x == 'Q')|(x == 'R'))
#                                                 else ('Light Yellow' if ((x == 'S')|(x == 'T')|(x == 'U')|(x == 'V')|(x == 'W')|(x == 'X')|(x == 'Y')|(x == 'Z')) else x)))))
# # diamond_df['Color Desp'] = diamond_df.color.apply(lambda x: 'Near Colourless' if ((x == 'G')|(x == 'H')|(x == 'I')|(x == 'J')) else x)
# # diamond_df['Color Desp'] = diamond_df.color.apply(lambda x: 'Faint' if ((x == 'K')|(x == 'L')|(x == 'M')) else x)
# # diamond_df['Color Desp'] = diamond_df.color.apply(lambda x: 'Very Light Yellow' if ((x == 'N')|(x == 'O')|(x == 'P')|(x == 'Q')|(x == 'R'))else x)
# diamond_df['Color Desp'] = diamond_df.color.apply(lambda x: 'Light Yellow' if ((x == 'S')|(x == 'T')|(x == 'U')|(x == 'V')|(x == 'W')|(x == 'X')|(x == 'Y')|(x == 'Z')) else x)

# %%
# diamond_df['Color Desp'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Color Desp'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
diamond_df.color.apply(lambda x: "Colourless" if (x =='D') | (x == 'E') | (x == 'F') 
                                                else ('Near Colourless' if (x == 'G')|(x == 'H')|(x == 'I')|(x == 'J') 
                                                else ('Faint' if (x == 'K')|(x == 'L')|(x == 'M') 
                                                else ('Very Light Yellow' if (x == 'N')|(x == 'O')|(x == 'P')|(x == 'Q')|(x == 'R')
                                                else ('Light Yellow' if (x == 'S')|(x == 'T')|(x == 'U')|(x == 'V')|(x == 'W')|(x == 'X') else x))))).unique()
# Out:
# array(['Colourless', 'Near Colourless'], dtype=object)

# %%
diamond_df['Color Desp'] = diamond_df.color

# %%
diamond_df['Color Desp'].replace({'D': 'Colourless', 'E': 'Colourless', 'F': 'Colourless',
                                 'G': 'Near Colourless', 'H': 'Near Colourless', 'I': 'Near Colourless', 'J': 'Near Colourless',
                                 'K': 'Faint', 'L': 'Faint', 'M': 'Faint', 
                                 'M': 'Very Light Yellow', 'O': 'Very Light Yellow', 'P': 'Very Light Yellow', 'Q': 'Very Light Yellow', 'R': 'Very Light Yellow',
                                 'S': 'Light Yellow', 'T': 'Light Yellow', 'U': 'Light Yellow', 'V': 'Light Yellow', 'W': 'Light Yellow', 'V': 'Light Yellow'}, inplace= True)

# %%
diamond_df['Color Desp'].unique()
# Out:
# array(['Colourless', 'Near Colourless'], dtype=object)

# %%
diamond_df.color.unique()
# Out:
# array(['E', 'I', 'J', 'H', 'F', 'G', 'D'], dtype=object)

# %%
diamond_df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#         Color Desp
# 0       Colourless
# 1       Colourless
# 2       Colourless
# 3  Near Colourless
# 4  Near Colourless

# %%
# Biggest diamond -> Dimension-wise

diamond_df.sort_values(by = ['x', 'y', 'z'] , ascending = False).head()
# Out:
#        carat        cut color clarity  depth  table  price      x      y  \
# 27415   5.01       Fair     J      I1   65.5   59.0  18018  10.74  10.54
# 27630   4.50       Fair     J      I1   65.8   58.0  18531  10.23  10.16
# 25998   4.01    Premium     I      I1   61.0   61.0  15223  10.14  10.10
# 25999   4.01    Premium     J      I1   62.5   62.0  15223  10.02   9.94
# 26444   4.00  Very Good     I      I1   63.3   58.0  15984  10.01   9.94
#
#           z       Color Desp
# 27415  6.98  Near Colourless
# 27630  6.72  Near Colourless
# 25998  6.17  Near Colourless
# 25999  6.24  Near Colourless
# 26444  6.31  Near Colourless

# %%
diamond_df.rename(columns = {'Color Desp': 'Color Desc'}, inplace = True)

# %%
diamond_df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#         Color Desc
# 0       Colourless
# 1       Colourless
# 2       Colourless
# 3  Near Colourless
# 4  Near Colourless

# %%
diamond_df['Clarity Desc'] = diamond_df['clarity'].replace({'F': 'No Inclusion', 'IF': 'No Inclusion',
                                                           'VVS1': 'Minute Inclusions', 'VVS2': 'Minute Inclusions',
                                                           'VS1': 'Minor Inclusions', 'VS2':'Minor Inclusions',
                                                           'SI1': 'Noticeable Inclusions', 'SI2': 'Noticeable Inclusions',
                                                           'I1': 'Obvious Included', 'I2': 'Obvious Included', 'I3': 'Obvious Included'})

# %%
diamond_df['Clarity Desc'].unique()
# Out:
# array(['Noticeable Inclusions', 'Minor Inclusions', 'Minute Inclusions',
#        'Obvious Included', 'No Inclusion'], dtype=object)

# %%
diamond_df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#         Color Desc           Clarity Desc
# 0       Colourless  Noticeable Inclusions
# 1       Colourless  Noticeable Inclusions
# 2       Colourless       Minor Inclusions
# 3  Near Colourless       Minor Inclusions
# 4  Near Colourless  Noticeable Inclusions

# %% [markdown]
# - Diamond Depth analysis

# %%
plt.hist(diamond_df.depth, bins = 100, color = 'red', histtype = 'bar', edgecolor = 'black' )
plt.show()

# %% [markdown]
# The depth of the diamonds in the datasheet all lies between a range of 55-70 which is close when compared to the ideal range 57.5 to 63%.

# %%
# diamonds which lies to between the in the ideal range of depth

diamond_df[(diamond_df.depth >= 57.5) & (diamond_df.depth <= 63)]
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 5       0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6       0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53934   0.72    Premium     D     SI1   62.7   59.0   2757  5.69  5.73  3.58
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# ...

# %%
# No of diamonds in the ideal range

diamond_df[(diamond_df.depth >= 57.5) & (diamond_df.depth <= 63)].shape[0]
# Out:
# 46539

# %% [markdown]
# - Diamond Table analysis

# %%
plt.hist(diamond_df.table, color = 'violet', edgecolor = 'blue', bins = 100)
plt.show()

# %% [markdown]
# The table size of in the dataset lies between a range of 52- 68% which is very close to the ideal range of 52-62%.

# %%
# Diamonds with ideal table size between 52-62%
diamond_df[(diamond_df.table >= 52) & (diamond_df.table <= 62)]
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5       0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# ...

# %% [markdown]
# Number of ideal table sized diamonds

# %%
diamond_df[(diamond_df.table >= 52) & (diamond_df.table <= 62)].shape[0]
# Out:
# 52727

# %%
diamond_df.sort_values(by= ['table', 'depth', 'carat'], ascending = False)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 24932   2.01       Fair     F     SI1   58.6   95.0  13387  8.32  8.31  4.87
# 50773   0.81       Fair     F     SI2   68.8   79.0   2301  5.26  5.20  3.58
# 51342   0.79       Fair     G     SI1   65.3   76.0   2362  5.52  5.13  3.35
# 52860   0.50       Fair     E     VS2   79.0   73.0   2579  5.21  5.18  4.09
# 52861   0.50       Fair     E     VS2   79.0   73.0   2579  5.21  5.18  4.09
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 25179   2.00       Fair     H     SI1   61.2   50.0  13764  8.17  8.08  4.97
# 22701   0.30       Fair     E     SI1   64.5   49.0    630  4.28  4.25  2.75
# 5979    1.00       Fair     I     VS1   64.0   49.0   3951  6.43  6.39  4.10
# 35633   0.29  Very Good     E     VS1   62.8   44.0    474  4.20  4.24  2.65
# 11368   1.04      Ideal     I     VS1   62.9   43.0   4997  6.45  6.41  4.04
#
# ...

# %% [markdown]
# So we have our clean cut colourless diamond which has a dept of 58.6 and table size 95 and weighs 2.01 carats

# %%
diamond_df.sort_values(by= ['carat','table', 'depth'], ascending = True)
# Out:
#        carat      cut color clarity  depth  table  price      x      y     z  \
# 31595   0.20    Ideal     E     VS2   59.7   55.0    367   3.86   3.84  2.30
# 31597   0.20    Ideal     D     VS2   61.5   57.0    367   3.81   3.77  2.33
# 31599   0.20    Ideal     E     VS2   62.2   57.0    367   3.76   3.73  2.33
# 31593   0.20  Premium     E     VS2   61.1   59.0    367   3.81   3.78  2.32
# 31596   0.20  Premium     F     VS2   62.6   59.0    367   3.73   3.71  2.33
# ...      ...      ...   ...     ...    ...    ...    ...    ...    ...   ...
# 25998   4.01  Premium     I      I1   61.0   61.0  15223  10.14  10.10  6.17
# 25999   4.01  Premium     J      I1   62.5   62.0  15223  10.02   9.94  6.24
# 27130   4.13     Fair     H      I1   64.8   61.0  17329  10.00   9.85  6.43
# 27630   4.50     Fair     J      I1   65.8   58.0  18531  10.23  10.16  6.72
# 27415   5.01     Fair     J      I1   65.5   59.0  18018  10.74  10.54  6.98
#
#             Color Desc      Clarity Desc
# ...

# %%
diamond_df.clarity.unique()
# Out:
# array(['SI2', 'SI1', 'VS1', 'VS2', 'VVS2', 'VVS1', 'I1', 'IF'],
#       dtype=object)

# %%
diamond_df[diamond_df.clarity == 'I1']
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 15      0.32    Premium     E      I1   60.9   58.0    345  4.38  4.42  2.68
# 172     1.17  Very Good     J      I1   60.2   61.0   2774  6.83  6.90  4.13
# 215     1.01    Premium     F      I1   61.8   60.0   2781  6.39  6.36  3.94
# 241     1.01       Fair     E      I1   64.5   58.0   2788  6.29  6.21  4.03
# 315     0.96      Ideal     F      I1   60.7   55.0   2801  6.37  6.41  3.88
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53649   1.05  Very Good     J      I1   59.6   63.0   2705  6.61  6.55  3.92
# 53692   1.00       Good     F      I1   64.2   59.0   2717  6.26  6.30  4.03
# 53745   1.00       Fair     G      I1   61.7   57.0   2723  6.39  6.28  3.91
# 53875   1.04  Very Good     I      I1   61.6   61.0   2745  6.45  6.47  3.98
# 53897   1.02       Good     H      I1   64.3   63.0   2751  6.28  6.23  4.02
#
#             Color Desc      Clarity Desc
# ...

# %%
plt.bar(diamond_df['Clarity Desc'].unique(), diamond_df['Clarity Desc'].value_counts().sort_values(ascending= True))

plt.title("Dimonds per clarity level\n", fontdict = {'fontsize': 20, 'fontweight': 15, 'color': 'Red'})
plt.xlabel("Clarity", fontdict = {'fontsize': 12, 'fontweight': 10, 'color':'brown'})
plt.ylabel("Count of diamonds", fontdict= {'fontsize': 12, 'fontweight': 10, 'color': 'brown'})
plt.xticks(rotation = 35)
plt.show()

# %%
plt.figure(figsize= (12, 8))
plt.pie(diamond_df['Clarity Desc'].value_counts(), labels = diamond_df['Clarity Desc'].unique(), autopct='%20.01f%%')
plt.show()

# %%
plt.bar(diamond_df.cut.unique(), diamond_df.cut.value_counts().sort_values(ascending = True))
plt.show()

# %%
plt.figure(figsize= (12, 8))
plt.pie(diamond_df.cut.value_counts(), labels = diamond_df.cut.unique(), autopct='%20.01f%%')
plt.show()

# %%
diamond_df['Color Desc'].value_counts()
# Out:
# Near Colourless    27826
# Colourless         26114
# Name: Color Desc, dtype: int64

# %%
plt.pie(diamond_df['Color Desc'].value_counts(), labels = diamond_df['Color Desc'].unique(), autopct = '%2.01f%%')
plt.show()

# %%
diamond_df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#         Color Desc           Clarity Desc
# 0       Colourless  Noticeable Inclusions
# 1       Colourless  Noticeable Inclusions
# 2       Colourless       Minor Inclusions
# 3  Near Colourless       Minor Inclusions
# 4  Near Colourless  Noticeable Inclusions

# %% [markdown]
# Distribution of diamond weights around the dataset

# %%
plt.hist(diamond_df.carat, bins = 100, color = 'yellow', edgecolor = 'green')
plt.show()

# %% [markdown]
# Lets observe the mean, and quartlies and outlier compared to the weight of the diamond

# %%
plt.boxplot(diamond_df.carat)
plt.show()

# %%
import seaborn as sns

# %%
sns.boxplot(diamond_df.carat)
# Out:
# <AxesSubplot:xlabel='carat'>

# %%
diamond_df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
diamond_df[diamond_df['carat'] >= 3]
# Out:
#        carat        cut color clarity  depth  table  price      x      y  \
# 16283   3.00  Very Good     H      I1   63.1   55.0   6512   9.23   9.10
# 19339   3.01    Premium     I      I1   62.7   58.0   8040   9.10   8.97
# 19346   3.00       Fair     H      I1   67.1   57.0   8044   8.93   8.84
# 21758   3.11       Fair     J      I1   65.9   57.0   9823   9.15   9.02
# 21862   3.01    Premium     F      I1   62.2   56.0   9925   9.24   9.13
# 22428   3.05    Premium     E      I1   60.9   58.0  10453   9.26   9.25
# 22540   3.02       Fair     I      I1   65.2   56.0  10577   9.11   9.02
# 22741   3.01       Fair     H      I1   56.1   62.0  10761   9.54   9.38
# 22831   3.00       Good     I      I1   57.0   64.0  10863   9.38   9.31
# 23539   3.00       Good     E      I1   64.2   65.0  11548   9.08   8.96
# 23644   3.65       Fair     H      I1   67.1   53.0  11668   9.53   9.48
# 24131   3.24    Premium     H      I1   62.1   58.0  12300   9.44   9.40
# ...

# %%
plt.figure(figsize = (12, 8))
plt.pie(diamond_df[diamond_df['carat'] >= 3]['Clarity Desc'].value_counts(), 
        labels = diamond_df[diamond_df['carat'] >= 3]['Clarity Desc'].unique(),
       autopct = '%1.01f%%')

plt.show()

# %% [markdown]
# In the range where diamond weight lies between 3 to 5.1 most of the diamond's clarity is low:
# - 60% - Obvious Included
# - 37.5% - Noticeable Inclusions
# - 2.5% - Inclusions

# %% [markdown]
# Most fine diamond in the dataset

# %%
diamond_df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#         Color Desc           Clarity Desc
# 0       Colourless  Noticeable Inclusions
# 1       Colourless  Noticeable Inclusions
# 2       Colourless       Minor Inclusions
# 3  Near Colourless       Minor Inclusions
# 4  Near Colourless  Noticeable Inclusions

# %%
diamond_df[(diamond_df['Clarity Desc'] == 'No Inclusion') & (diamond_df['cut'] == 'Ideal')].sort_values(by = ['carat', 'z', 'y', 'x', 'table', 'depth', 'clarity'], ascending = False)
# Out:
#        carat    cut color clarity  depth  table  price     x     y     z  \
# 27400   2.08  Ideal     J      IF   61.0   55.0  17986  8.32  8.25  5.05
# 27129   2.04  Ideal     J      IF   61.5   58.0  17327  8.11  8.14  5.00
# 25765   1.66  Ideal     H      IF   61.5   57.0  14724  7.59  7.62  4.68
# 25831   1.66  Ideal     H      IF   61.5   57.0  14859  7.62  7.59  4.68
# 27219   1.65  Ideal     G      IF   62.4   55.0  17569  7.53  7.61  4.72
# ...      ...    ...   ...     ...    ...    ...    ...   ...   ...   ...
# 1395    0.24  Ideal     G      IF   60.8   58.0    559  4.01  4.05  2.44
# 28683   0.24  Ideal     F      IF   60.7   57.0    678  3.99  4.04  2.43
# 48323   0.23  Ideal     G      IF   62.8   55.0    536  3.93  3.96  2.48
# 48324   0.23  Ideal     G      IF   61.7   55.0    536  3.94  3.98  2.44
# 48322   0.23  Ideal     G      IF   61.8   56.0    536  3.92  3.94  2.43
#
#             Color Desc  Clarity Desc
# 27400  Near Colourless  No Inclusion
# ...

# %%
diamond_df['Clarity Desc'].unique()
# Out:
# array(['Noticeable Inclusions', 'Minor Inclusions', 'Minute Inclusions',
#        'Obvious Included', 'No Inclusion'], dtype=object)

# %% [markdown]
# **Price Analysis**

# %%
diamond_df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#         Color Desc           Clarity Desc
# 0       Colourless  Noticeable Inclusions
# 1       Colourless  Noticeable Inclusions
# 2       Colourless       Minor Inclusions
# 3  Near Colourless       Minor Inclusions
# 4  Near Colourless  Noticeable Inclusions

# %% [markdown]
# Price Variation compared to Color of the diamond

# %%
diamond_df.groupby(by = 'Color Desc').mean()
# Out:
#                     carat      depth      table        price         x  \
# Color Desc
# Colourless       0.686595  61.683312  57.447660  3337.759401  5.487314
# Near Colourless  0.902434  61.811432  57.466122  4491.230073  5.959997
#
#                         y         z
# Color Desc
# Colourless       5.492809  3.386464
# Near Colourless  5.961371  3.681635

# %% [markdown]
# It can be seen from the above statistics that the average price of the Near Colourless diamond is greater than colourless diamond but it should also be taken into account that average weight of near Colourless diamond is greater than that of Colourless diamond.
#
# But the depth and table size of the diamond categories have same dimensions.

# %%
plt.figure(figsize = (12, 5))
sns.boxplot(diamond_df['price'])
plt.show()

# %% [markdown]
# - **Price VS Diamond Color**

# %%
sns.boxplot(x = diamond_df.price, y = diamond_df['Color Desc'])
plt.show()

# %% [markdown]
# From the boxplot above it can be concluded that the colourless diamond have a if excluding the outliers cost below 10,000 compared to Near Colourless diamond which is much higher.

# %% [markdown]
# - **Weight vs Diamond Color**

# %%
plt.figure(figsize = (12, 5))
plt.scatter(diamond_df.price, diamond_df.carat, alpha = 0.7, marker = 'x')

plt.title('Weight VS Diamond Color\n', fontdict = {'fontweight': 20, 'fontsize': 20, 'color': 'red'})

plt.xlabel('Price', fontdict = {'fontweight': 20, 'fontsize': 12, 'color': 'blue'})
plt.ylabel('Weight(in Carats)', fontdict = {'fontweight': 20, 'fontsize': 12, 'color': 'blue'})

plt.show()

# %% [markdown]
# It can be observed that there are diamonds between 0.8 - 2.5 carats which weights more than 17500

# %%
diamond_df[(diamond_df['price'] > 17500)].sort_values(by = 'carat', ascending = True)
# Out:
#        carat        cut color clarity  depth  table  price      x      y  \
# 27226   1.03      Ideal     D      IF   62.0   56.0  17590   6.55   6.44
# 27635   1.04  Very Good     D      IF   61.3   56.0  18542   6.53   6.55
# 27530   1.07    Premium     D      IF   60.9   58.0  18279   6.67   6.57
# 27457   1.07  Very Good     D      IF   60.9   58.0  18114   6.57   6.67
# 27349   1.07  Very Good     D      IF   59.0   59.0  17909   6.63   6.72
# ...      ...        ...   ...     ...    ...    ...    ...    ...    ...
# 27515   3.01       Fair     I     SI2   65.8   56.0  18242   8.99   8.94
# 27638   3.04    Premium     I     SI2   59.3   60.0  18559   9.51   9.46
# 27679   3.51    Premium     J     VS2   62.5   59.0  18701   9.66   9.63
# 27630   4.50       Fair     J      I1   65.8   58.0  18531  10.23  10.16
# 27415   5.01       Fair     J      I1   65.5   59.0  18018  10.74  10.54
#
#           z       Color Desc           Clarity Desc
# ...

# %% [markdown]
# **Price vs Table**

# %%
sns.boxplot(diamond_df['table'], diamond_df['Color Desc'])
# Out:
# <AxesSubplot:xlabel='table', ylabel='Color Desc'>

# %% [markdown]
# It can be observed from the dataset that there exists a diamond which which has table dimension above 90 and it is colourless

# %%
diamond_df[diamond_df['table']> 77]
# Out:
#        carat   cut color clarity  depth  table  price     x     y     z  \
# 24932   2.01  Fair     F     SI1   58.6   95.0  13387  8.32  8.31  4.87
# 50773   0.81  Fair     F     SI2   68.8   79.0   2301  5.26  5.20  3.58
#
#        Color Desc           Clarity Desc
# 24932  Colourless  Noticeable Inclusions
# 50773  Colourless  Noticeable Inclusions

# %% [markdown]
# **Most costliest colourless diamond**

# %%
diamond_df[(diamond_df['Color Desc'] == "Colourless")].sort_values(by = 'price', ascending = False).head(10)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 27740   1.71    Premium     F     VS2   62.3   59.0  18791  7.57  7.53  4.70
# 27737   2.05    Premium     F     SI2   60.2   59.0  18784  8.28  8.33  5.00
# 27735   1.60      Ideal     F     VS1   62.0   56.0  18780  7.47  7.52  4.65
# 27733   1.51  Very Good     F    VVS1   62.6   59.0  18777  7.33  7.24  4.56
# 27729   2.00  Very Good     F     SI1   57.9   60.0  18759  8.28  8.34  4.81
# 27721   1.94    Premium     F     SI1   62.6   58.0  18735  7.91  7.87  4.94
# 27720   2.02  Very Good     E     SI1   59.8   59.0  18731  8.11  8.20  4.88
# 27688   1.51      Ideal     E     VS1   61.5   57.0  18729  7.34  7.40  4.53
# 27686   2.18    Premium     F     SI1   61.2   60.0  18717  8.38  8.30  5.10
# 27683   2.00  Very Good     E     SI1   60.5   59.0  18709  8.09  8.14  4.94
#
#        Color Desc           Clarity Desc
# 27740  Colourless       Minor Inclusions
# ...

# %% [markdown]
# **Most Costliest Near Colorless Diamond**

# %%
diamond_df[(diamond_df['Color Desc'] == "Near Colourless")].sort_values(by = 'price', ascending = False).head(10)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 27749   2.29    Premium     I     VS2   60.8   60.0  18823  8.50  8.47  5.16
# 27748   2.00  Very Good     G     SI1   63.5   56.0  18818  7.90  7.97  5.04
# 27747   1.51      Ideal     G      IF   61.7   55.0  18806  7.37  7.41  4.56
# 27746   2.07      Ideal     G     SI2   62.5   55.0  18804  8.20  8.13  5.11
# 27745   2.00  Very Good     H     SI1   62.8   57.0  18803  7.95  8.00  5.01
# 27744   2.29    Premium     I     SI1   61.8   59.0  18797  8.52  8.45  5.24
# 27743   2.00    Premium     I     VS1   60.8   59.0  18795  8.13  8.02  4.91
# 27742   2.04    Premium     H     SI1   58.1   60.0  18795  8.37  8.28  4.84
# 27741   2.15      Ideal     G     SI2   62.6   54.0  18791  8.29  8.35  5.21
# 27739   2.80       Good     G     SI2   63.8   58.0  18788  8.90  8.85  0.00
#
#             Color Desc           Clarity Desc
# 27749  Near Colourless       Minor Inclusions
# ...

# %% [markdown]
# **Diamond Cut Analysis**

# %%
sns.boxplot(diamond_df['price'], diamond_df['cut'])
# Out:
# <AxesSubplot:xlabel='price', ylabel='cut'>

# %% [markdown]
# From the above boxplot it can be denoted that diamond with premium cut has the highest IQR compared to others

# %% [markdown]
# **Count of diamonds based on their cut**

# %%
sns.barplot(x = diamond_df['cut'].unique(), y = diamond_df['cut'].value_counts() )
plt.show()

# %% [markdown]
# Let's find the relation which attribute is highly correlated with the price attribute

# %%
plt.figure(figsize = (10, 5))
sns.heatmap(diamond_df.corr(), cbar=True, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# It can be inferred from the above heatmap that price is highly correlated with:
# - carat
# - x
# - y
# - z
